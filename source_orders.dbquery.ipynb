-- %%
create table orders
(
  order_id int,
  order_date date,
  customer_id int,
  order_status string
);

insert into orders values
(1,'2020-01-01',1,'completed'),
(2,'2020-01-02',2,'pending'),
(3,'2020-01-03',3,'completed'),
(4,'2020-01-04',4,'cancelled'),
(5,'2020-01-05',5,'completed');

select * from orders;


insert into orders values
(1,'2025-11-11',7,'completed');





--Insert few more data for testing
insert into orders values
(6,'2025-11-12',8,'completed'),
(7,'2025-11-13',9,'completed'),
(8,'2025-11-14',10,'completed');
